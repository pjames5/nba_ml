# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import mean_squared_error


# %matplotlib inline

# %% [markdown]
# # Load the NBA statistical data from Kaggle
# https://www.kaggle.com/drgilermo/nba-players-stats

# %%
data = pd.read_csv('data/Seasons_Stats.csv')
# data.loc[data['Player'] == 'LeBron James'].T
data.T
# Out:
#                       0             1              2           3      \
# Unnamed: 0                0             1              2           3
# Year                   1950          1950           1950        1950
# Player      Curly Armstrong  Cliff Barker  Leo Barnhorst  Ed Bartels
# Pos                     G-F            SG             SF           F
# Age                      31            29             25          24
# Tm                      FTW           INO            CHS         TOT
# G                        63            49             67          15
# GS                      NaN           NaN            NaN         NaN
# MP                      NaN           NaN            NaN         NaN
# PER                     NaN           NaN            NaN         NaN
# TS%                   0.368         0.435          0.394       0.312
# 3PAr                    NaN           NaN            NaN         NaN
# FTr                   0.467         0.387          0.259       0.395
# ORB%                    NaN           NaN            NaN         NaN
# DRB%                    NaN           NaN            NaN         NaN
# TRB%                    NaN           NaN            NaN         NaN
# AST%                    NaN           NaN            NaN         NaN
# STL%                    NaN           NaN            NaN         NaN
# BLK%                    NaN           NaN            NaN         NaN
# TOV%                    NaN           NaN            NaN         NaN
# USG%                    NaN           NaN            NaN         NaN
# blanl                   NaN           NaN            NaN         NaN
# OWS                    -0.1           1.6            0.9        -0.5
# DWS                     3.6           0.6            2.8        -0.1
# WS                      3.5           2.2            3.6        -0.6
# WS/48                   NaN           NaN            NaN         NaN
# blank2                  NaN           NaN            NaN         NaN
# OBPM                    NaN           NaN            NaN         NaN
# DBPM                    NaN           NaN            NaN         NaN
# BPM                     NaN           NaN            NaN         NaN
# VORP                    NaN           NaN            NaN         NaN
# FG                      144           102            174          22
# FGA                     516           274            499          86
# FG%                   0.279         0.372          0.349       0.256
# 3P                      NaN           NaN            NaN         NaN
# 3PA                     NaN           NaN            NaN         NaN
# 3P%                     NaN           NaN            NaN         NaN
# 2P                      144           102            174          22
# 2PA                     516           274            499          86
# 2P%                   0.279         0.372          0.349       0.256
# eFG%                  0.279         0.372          0.349       0.256
# FT                      170            75             90          19
# FTA                     241           106            129          34
# FT%                   0.705         0.708          0.698       0.559
# ORB                     NaN           NaN            NaN         NaN
# DRB                     NaN           NaN            NaN         NaN
# TRB                     NaN           NaN            NaN         NaN
# AST                     176           109            140          20
# STL                     NaN           NaN            NaN         NaN
# BLK                     NaN           NaN            NaN         NaN
# TOV                     NaN           NaN            NaN         NaN
# PF                      217            99            192          29
# PTS                     458           279            438          63
#
#                  4           5            6           7              8      \
# Unnamed: 0           4           5            6           7              8
# Year              1950        1950         1950        1950           1950
# Player      Ed Bartels  Ed Bartels  Ralph Beard  Gene Berce  Charlie Black
# Pos                  F           F            G         G-F            F-C
# Age                 24          24           22          23             28
# Tm                 DNN         NYK          INO         TRI            TOT
# G                   13           2           60           3             65
# GS                 NaN         NaN          NaN         NaN            NaN
# MP                 NaN         NaN          NaN         NaN            NaN
# PER                NaN         NaN          NaN         NaN            NaN
# TS%              0.308       0.376        0.422       0.275          0.346
# 3PAr               NaN         NaN          NaN         NaN            NaN
# FTr              0.378        0.75        0.301       0.313          0.395
# ORB%               NaN         NaN          NaN         NaN            NaN
# DRB%               NaN         NaN          NaN         NaN            NaN
# TRB%               NaN         NaN          NaN         NaN            NaN
# AST%               NaN         NaN          NaN         NaN            NaN
# STL%               NaN         NaN          NaN         NaN            NaN
# BLK%               NaN         NaN          NaN         NaN            NaN
# TOV%               NaN         NaN          NaN         NaN            NaN
# USG%               NaN         NaN          NaN         NaN            NaN
# blanl              NaN         NaN          NaN         NaN            NaN
# OWS               -0.5           0          3.6        -0.1           -2.2
# DWS               -0.1           0          1.2           0              5
# WS                -0.6           0          4.8        -0.1            2.8
# WS/48              NaN         NaN          NaN         NaN            NaN
# blank2             NaN         NaN          NaN         NaN            NaN
# OBPM               NaN         NaN          NaN         NaN            NaN
# DBPM               NaN         NaN          NaN         NaN            NaN
# BPM                NaN         NaN          NaN         NaN            NaN
# VORP               NaN         NaN          NaN         NaN            NaN
# FG                  21           1          340           5            226
# FGA                 82           4          936          16            813
# FG%              0.256        0.25        0.363       0.313          0.278
# 3P                 NaN         NaN          NaN         NaN            NaN
# 3PA                NaN         NaN          NaN         NaN            NaN
# 3P%                NaN         NaN          NaN         NaN            NaN
# 2P                  21           1          340           5            226
# 2PA                 82           4          936          16            813
# 2P%              0.256        0.25        0.363       0.313          0.278
# eFG%             0.256        0.25        0.363       0.313          0.278
# FT                  17           2          215           0            209
# FTA                 31           3          282           5            321
# FT%              0.548       0.667        0.762           0          0.651
# ORB                NaN         NaN          NaN         NaN            NaN
# DRB                NaN         NaN          NaN         NaN            NaN
# TRB                NaN         NaN          NaN         NaN            NaN
# AST                 20           0          233           2            163
# STL                NaN         NaN          NaN         NaN            NaN
# BLK                NaN         NaN          NaN         NaN            NaN
# TOV                NaN         NaN          NaN         NaN            NaN
# PF                  27           2          132           6            273
# PTS                 59           4          895          10            661
#
#                     9      ...         24681        24682      24683  \
# Unnamed: 0              9  ...         24681        24682      24683
# Year                 1950  ...          2017         2017       2017
# Player      Charlie Black  ...  Delon Wright  James Young  Joe Young
# Pos                   F-C  ...            PG           SG         PG
# Age                    28  ...            24           21         24
# Tm                    FTW  ...           TOR          BOS        IND
# G                      36  ...            27           29         33
# GS                    NaN  ...             0            0          0
# MP                    NaN  ...           446          220        135
# PER                   NaN  ...            15           10       11.4
# TS%                 0.362  ...         0.535        0.549      0.433
# 3PAr                  NaN  ...         0.259        0.603      0.319
# FTr                  0.48  ...         0.474        0.155      0.208
# ORB%                  NaN  ...           4.1          3.1        0.8
# DRB%                  NaN  ...           8.1           10       13.1
# TRB%                  NaN  ...           6.1          6.6        7.1
# AST%                  NaN  ...          18.2          2.6         18
# STL%                  NaN  ...           3.1          2.3        1.5
# BLK%                  NaN  ...           2.1          0.7          0
# TOV%                  NaN  ...          15.1          6.1          6
# USG%                  NaN  ...          16.6         13.3       27.8
# blanl                 NaN  ...           NaN          NaN        NaN
# OWS                  -0.7  ...           0.5          0.1       -0.2
# DWS                   2.2  ...           0.6          0.2        0.1
# WS                    1.5  ...           1.1          0.3       -0.1
# WS/48                 NaN  ...         0.117        0.076     -0.022
# blank2                NaN  ...           NaN          NaN        NaN
# OBPM                  NaN  ...          -0.1           -2       -3.5
# DBPM                  NaN  ...           1.2         -1.1       -3.8
# BPM                   NaN  ...           1.1         -3.1       -7.3
# VORP                  NaN  ...           0.4         -0.1       -0.2
# FG                    125  ...            49           25         26
# FGA                   435  ...           116           58         72
# FG%                 0.287  ...         0.422        0.431      0.361
# 3P                    NaN  ...            10           12          5
# 3PA                   NaN  ...            30           35         23
# 3P%                   NaN  ...         0.333        0.343      0.217
# 2P                    125  ...            39           13         21
# 2PA                   435  ...            86           23         49
# 2P%                 0.287  ...         0.453        0.565      0.429
# eFG%                0.287  ...         0.466        0.534      0.396
# FT                    132  ...            42            6         11
# FTA                   209  ...            55            9         15
# FT%                 0.632  ...         0.764        0.667      0.733
# ORB                   NaN  ...            16            6          1
# DRB                   NaN  ...            32           20         16
# TRB                   NaN  ...            48           26         17
# AST                    75  ...            57            4         15
# STL                   NaN  ...            27           10          4
# BLK                   NaN  ...            11            2          0
# TOV                   NaN  ...            25            4          5
# PF                    140  ...            31           15          5
# PTS                   382  ...           150           68         68
#
#                  24684           24685        24686         24687  \
# Unnamed: 0       24684           24685        24686         24687
# Year              2017            2017         2017          2017
# Player      Nick Young  Thaddeus Young  Cody Zeller  Tyler Zeller
# Pos                 SG              PF           PF             C
# Age                 31              28           24            27
# Tm                 LAL             IND          CHO           BOS
# G                   60              74           62            51
# GS                  60              74           58             5
# MP                1556            2237         1725           525
# PER               14.1            14.9         16.7            13
# TS%              0.588           0.562        0.604         0.508
# 3PAr             0.665           0.172        0.002         0.006
# FTr              0.142           0.125        0.442         0.247
# ORB%               1.7             6.7          8.6           9.2
# DRB%               8.2            15.8         17.3            17
# TRB%               4.8            11.3         12.9          13.2
# AST%               5.8             8.4          9.1          12.2
# STL%               1.2             2.6          1.8           0.7
# BLK%               0.7             1.2            3           3.3
# TOV%               5.1            11.7         10.9          10.2
# USG%              19.5            16.5         15.5          16.5
# blanl              NaN             NaN          NaN           NaN
# OWS                  3             1.9          3.4           0.5
# DWS                0.2             2.7          2.2           0.6
# WS                 3.2             4.6          5.6             1
# WS/48            0.098           0.099        0.157         0.094
# blank2             NaN             NaN          NaN           NaN
# OBPM               2.6               0         -0.2          -3.2
# DBPM              -3.4             1.5          2.3           0.8
# BPM               -0.7             1.5          2.1          -2.5
# VORP               0.5               2          1.8          -0.1
# FG                 272             362          253            78
# FGA                633             687          443           158
# FG%               0.43           0.527        0.571         0.494
# 3P                 170              45            0             0
# 3PA                421             118            1             1
# 3P%              0.404           0.381            0             0
# 2P                 102             317          253            78
# 2PA                212             569          442           157
# 2P%              0.481           0.557        0.572         0.497
# eFG%             0.564            0.56        0.571         0.494
# FT                  77              45          133            22
# FTA                 90              86          196            39
# FT%              0.856           0.523        0.679         0.564
# ORB                 25             131          135            43
# DRB                112             318          270            81
# TRB                137             449          405           124
# AST                 58             122           99            42
# STL                 37             114           62             7
# BLK                 14              30           58            21
# TOV                 36              96           65            20
# PF                 137             135          189            61
# PTS                791             814          639           178
#
#                         24688        24689        24690
# Unnamed: 0              24688        24689        24690
# Year                     2017         2017         2017
# Player      Stephen Zimmerman  Paul Zipser  Ivica Zubac
# Pos                         C           SF            C
# Age                        20           22           19
# Tm                        ORL          CHI          LAL
# G                          19           44           38
# GS                          0           18           11
# MP                        108          843          609
# PER                       7.3          6.9           17
# TS%                     0.346        0.503        0.547
# 3PAr                        0        0.448        0.013
# FTr                     0.161        0.181        0.206
# ORB%                     10.8          1.9          7.1
# DRB%                     24.9         14.2         21.9
# TRB%                     17.6            8         14.3
# AST%                      5.3          6.1          8.1
# STL%                      0.9          0.9          1.1
# BLK%                      3.7          1.5          4.4
# TOV%                      8.3         14.4         10.4
# USG%                     14.8         14.4         20.3
# blanl                     NaN          NaN          NaN
# OWS                      -0.1         -0.3          0.6
# DWS                       0.1          0.8          0.5
# WS                          0          0.5          1.1
# WS/48                  -0.005         0.03        0.086
# blank2                    NaN          NaN          NaN
# OBPM                     -7.8         -3.6         -2.7
# DBPM                      0.4         -0.1          0.3
# BPM                      -7.3         -3.7         -2.5
# VORP                     -0.1         -0.4         -0.1
# FG                         10           88          126
# FGA                        31          221          238
# FG%                     0.323        0.398        0.529
# 3P                          0           33            0
# 3PA                         0           99            3
# 3P%                       NaN        0.333            0
# 2P                         10           55          126
# 2PA                        31          122          235
# 2P%                     0.323        0.451        0.536
# eFG%                    0.323        0.473        0.529
# FT                          3           31           32
# FTA                         5           40           49
# FT%                       0.6        0.775        0.653
# ORB                        11           15           41
# DRB                        24          110          118
# TRB                        35          125          159
# AST                         4           36           30
# STL                         2           15           14
# BLK                         5           16           33
# TOV                         3           40           30
# PF                         17           78           66
# PTS                        23          240          284
#
# [53 rows x 24691 columns]

# %%
# check the shape
data.shape
# Out:
# (24691, 53)

# %% [markdown]
# # clean it up a little

# %%
data = data.replace('?', np.nan)
data.T
# Out:
#                       0             1              2           3      \
# Unnamed: 0                0             1              2           3
# Year                   1950          1950           1950        1950
# Player      Curly Armstrong  Cliff Barker  Leo Barnhorst  Ed Bartels
# Pos                     G-F            SG             SF           F
# Age                      31            29             25          24
# Tm                      FTW           INO            CHS         TOT
# G                        63            49             67          15
# GS                      NaN           NaN            NaN         NaN
# MP                      NaN           NaN            NaN         NaN
# PER                     NaN           NaN            NaN         NaN
# TS%                   0.368         0.435          0.394       0.312
# 3PAr                    NaN           NaN            NaN         NaN
# FTr                   0.467         0.387          0.259       0.395
# ORB%                    NaN           NaN            NaN         NaN
# DRB%                    NaN           NaN            NaN         NaN
# TRB%                    NaN           NaN            NaN         NaN
# AST%                    NaN           NaN            NaN         NaN
# STL%                    NaN           NaN            NaN         NaN
# BLK%                    NaN           NaN            NaN         NaN
# TOV%                    NaN           NaN            NaN         NaN
# USG%                    NaN           NaN            NaN         NaN
# blanl                   NaN           NaN            NaN         NaN
# OWS                    -0.1           1.6            0.9        -0.5
# DWS                     3.6           0.6            2.8        -0.1
# WS                      3.5           2.2            3.6        -0.6
# WS/48                   NaN           NaN            NaN         NaN
# blank2                  NaN           NaN            NaN         NaN
# OBPM                    NaN           NaN            NaN         NaN
# DBPM                    NaN           NaN            NaN         NaN
# BPM                     NaN           NaN            NaN         NaN
# VORP                    NaN           NaN            NaN         NaN
# FG                      144           102            174          22
# FGA                     516           274            499          86
# FG%                   0.279         0.372          0.349       0.256
# 3P                      NaN           NaN            NaN         NaN
# 3PA                     NaN           NaN            NaN         NaN
# 3P%                     NaN           NaN            NaN         NaN
# 2P                      144           102            174          22
# 2PA                     516           274            499          86
# 2P%                   0.279         0.372          0.349       0.256
# eFG%                  0.279         0.372          0.349       0.256
# FT                      170            75             90          19
# FTA                     241           106            129          34
# FT%                   0.705         0.708          0.698       0.559
# ORB                     NaN           NaN            NaN         NaN
# DRB                     NaN           NaN            NaN         NaN
# TRB                     NaN           NaN            NaN         NaN
# AST                     176           109            140          20
# STL                     NaN           NaN            NaN         NaN
# BLK                     NaN           NaN            NaN         NaN
# TOV                     NaN           NaN            NaN         NaN
# PF                      217            99            192          29
# PTS                     458           279            438          63
#
#                  4           5            6           7              8      \
# Unnamed: 0           4           5            6           7              8
# Year              1950        1950         1950        1950           1950
# Player      Ed Bartels  Ed Bartels  Ralph Beard  Gene Berce  Charlie Black
# Pos                  F           F            G         G-F            F-C
# Age                 24          24           22          23             28
# Tm                 DNN         NYK          INO         TRI            TOT
# G                   13           2           60           3             65
# GS                 NaN         NaN          NaN         NaN            NaN
# MP                 NaN         NaN          NaN         NaN            NaN
# PER                NaN         NaN          NaN         NaN            NaN
# TS%              0.308       0.376        0.422       0.275          0.346
# 3PAr               NaN         NaN          NaN         NaN            NaN
# FTr              0.378        0.75        0.301       0.313          0.395
# ORB%               NaN         NaN          NaN         NaN            NaN
# DRB%               NaN         NaN          NaN         NaN            NaN
# TRB%               NaN         NaN          NaN         NaN            NaN
# AST%               NaN         NaN          NaN         NaN            NaN
# STL%               NaN         NaN          NaN         NaN            NaN
# BLK%               NaN         NaN          NaN         NaN            NaN
# TOV%               NaN         NaN          NaN         NaN            NaN
# USG%               NaN         NaN          NaN         NaN            NaN
# blanl              NaN         NaN          NaN         NaN            NaN
# OWS               -0.5           0          3.6        -0.1           -2.2
# DWS               -0.1           0          1.2           0              5
# WS                -0.6           0          4.8        -0.1            2.8
# WS/48              NaN         NaN          NaN         NaN            NaN
# blank2             NaN         NaN          NaN         NaN            NaN
# OBPM               NaN         NaN          NaN         NaN            NaN
# DBPM               NaN         NaN          NaN         NaN            NaN
# BPM                NaN         NaN          NaN         NaN            NaN
# VORP               NaN         NaN          NaN         NaN            NaN
# FG                  21           1          340           5            226
# FGA                 82           4          936          16            813
# FG%              0.256        0.25        0.363       0.313          0.278
# 3P                 NaN         NaN          NaN         NaN            NaN
# 3PA                NaN         NaN          NaN         NaN            NaN
# 3P%                NaN         NaN          NaN         NaN            NaN
# 2P                  21           1          340           5            226
# 2PA                 82           4          936          16            813
# 2P%              0.256        0.25        0.363       0.313          0.278
# eFG%             0.256        0.25        0.363       0.313          0.278
# FT                  17           2          215           0            209
# FTA                 31           3          282           5            321
# FT%              0.548       0.667        0.762           0          0.651
# ORB                NaN         NaN          NaN         NaN            NaN
# DRB                NaN         NaN          NaN         NaN            NaN
# TRB                NaN         NaN          NaN         NaN            NaN
# AST                 20           0          233           2            163
# STL                NaN         NaN          NaN         NaN            NaN
# BLK                NaN         NaN          NaN         NaN            NaN
# TOV                NaN         NaN          NaN         NaN            NaN
# PF                  27           2          132           6            273
# PTS                 59           4          895          10            661
#
#                     9      ...         24681        24682      24683  \
# Unnamed: 0              9  ...         24681        24682      24683
# Year                 1950  ...          2017         2017       2017
# Player      Charlie Black  ...  Delon Wright  James Young  Joe Young
# Pos                   F-C  ...            PG           SG         PG
# Age                    28  ...            24           21         24
# Tm                    FTW  ...           TOR          BOS        IND
# G                      36  ...            27           29         33
# GS                    NaN  ...             0            0          0
# MP                    NaN  ...           446          220        135
# PER                   NaN  ...            15           10       11.4
# TS%                 0.362  ...         0.535        0.549      0.433
# 3PAr                  NaN  ...         0.259        0.603      0.319
# FTr                  0.48  ...         0.474        0.155      0.208
# ORB%                  NaN  ...           4.1          3.1        0.8
# DRB%                  NaN  ...           8.1           10       13.1
# TRB%                  NaN  ...           6.1          6.6        7.1
# AST%                  NaN  ...          18.2          2.6         18
# STL%                  NaN  ...           3.1          2.3        1.5
# BLK%                  NaN  ...           2.1          0.7          0
# TOV%                  NaN  ...          15.1          6.1          6
# USG%                  NaN  ...          16.6         13.3       27.8
# blanl                 NaN  ...           NaN          NaN        NaN
# OWS                  -0.7  ...           0.5          0.1       -0.2
# DWS                   2.2  ...           0.6          0.2        0.1
# WS                    1.5  ...           1.1          0.3       -0.1
# WS/48                 NaN  ...         0.117        0.076     -0.022
# blank2                NaN  ...           NaN          NaN        NaN
# OBPM                  NaN  ...          -0.1           -2       -3.5
# DBPM                  NaN  ...           1.2         -1.1       -3.8
# BPM                   NaN  ...           1.1         -3.1       -7.3
# VORP                  NaN  ...           0.4         -0.1       -0.2
# FG                    125  ...            49           25         26
# FGA                   435  ...           116           58         72
# FG%                 0.287  ...         0.422        0.431      0.361
# 3P                    NaN  ...            10           12          5
# 3PA                   NaN  ...            30           35         23
# 3P%                   NaN  ...         0.333        0.343      0.217
# 2P                    125  ...            39           13         21
# 2PA                   435  ...            86           23         49
# 2P%                 0.287  ...         0.453        0.565      0.429
# eFG%                0.287  ...         0.466        0.534      0.396
# FT                    132  ...            42            6         11
# FTA                   209  ...            55            9         15
# FT%                 0.632  ...         0.764        0.667      0.733
# ORB                   NaN  ...            16            6          1
# DRB                   NaN  ...            32           20         16
# TRB                   NaN  ...            48           26         17
# AST                    75  ...            57            4         15
# STL                   NaN  ...            27           10          4
# BLK                   NaN  ...            11            2          0
# TOV                   NaN  ...            25            4          5
# PF                    140  ...            31           15          5
# PTS                   382  ...           150           68         68
#
#                  24684           24685        24686         24687  \
# Unnamed: 0       24684           24685        24686         24687
# Year              2017            2017         2017          2017
# Player      Nick Young  Thaddeus Young  Cody Zeller  Tyler Zeller
# Pos                 SG              PF           PF             C
# Age                 31              28           24            27
# Tm                 LAL             IND          CHO           BOS
# G                   60              74           62            51
# GS                  60              74           58             5
# MP                1556            2237         1725           525
# PER               14.1            14.9         16.7            13
# TS%              0.588           0.562        0.604         0.508
# 3PAr             0.665           0.172        0.002         0.006
# FTr              0.142           0.125        0.442         0.247
# ORB%               1.7             6.7          8.6           9.2
# DRB%               8.2            15.8         17.3            17
# TRB%               4.8            11.3         12.9          13.2
# AST%               5.8             8.4          9.1          12.2
# STL%               1.2             2.6          1.8           0.7
# BLK%               0.7             1.2            3           3.3
# TOV%               5.1            11.7         10.9          10.2
# USG%              19.5            16.5         15.5          16.5
# blanl              NaN             NaN          NaN           NaN
# OWS                  3             1.9          3.4           0.5
# DWS                0.2             2.7          2.2           0.6
# WS                 3.2             4.6          5.6             1
# WS/48            0.098           0.099        0.157         0.094
# blank2             NaN             NaN          NaN           NaN
# OBPM               2.6               0         -0.2          -3.2
# DBPM              -3.4             1.5          2.3           0.8
# BPM               -0.7             1.5          2.1          -2.5
# VORP               0.5               2          1.8          -0.1
# FG                 272             362          253            78
# FGA                633             687          443           158
# FG%               0.43           0.527        0.571         0.494
# 3P                 170              45            0             0
# 3PA                421             118            1             1
# 3P%              0.404           0.381            0             0
# 2P                 102             317          253            78
# 2PA                212             569          442           157
# 2P%              0.481           0.557        0.572         0.497
# eFG%             0.564            0.56        0.571         0.494
# FT                  77              45          133            22
# FTA                 90              86          196            39
# FT%              0.856           0.523        0.679         0.564
# ORB                 25             131          135            43
# DRB                112             318          270            81
# TRB                137             449          405           124
# AST                 58             122           99            42
# STL                 37             114           62             7
# BLK                 14              30           58            21
# TOV                 36              96           65            20
# PF                 137             135          189            61
# PTS                791             814          639           178
#
#                         24688        24689        24690
# Unnamed: 0              24688        24689        24690
# Year                     2017         2017         2017
# Player      Stephen Zimmerman  Paul Zipser  Ivica Zubac
# Pos                         C           SF            C
# Age                        20           22           19
# Tm                        ORL          CHI          LAL
# G                          19           44           38
# GS                          0           18           11
# MP                        108          843          609
# PER                       7.3          6.9           17
# TS%                     0.346        0.503        0.547
# 3PAr                        0        0.448        0.013
# FTr                     0.161        0.181        0.206
# ORB%                     10.8          1.9          7.1
# DRB%                     24.9         14.2         21.9
# TRB%                     17.6            8         14.3
# AST%                      5.3          6.1          8.1
# STL%                      0.9          0.9          1.1
# BLK%                      3.7          1.5          4.4
# TOV%                      8.3         14.4         10.4
# USG%                     14.8         14.4         20.3
# blanl                     NaN          NaN          NaN
# OWS                      -0.1         -0.3          0.6
# DWS                       0.1          0.8          0.5
# WS                          0          0.5          1.1
# WS/48                  -0.005         0.03        0.086
# blank2                    NaN          NaN          NaN
# OBPM                     -7.8         -3.6         -2.7
# DBPM                      0.4         -0.1          0.3
# BPM                      -7.3         -3.7         -2.5
# VORP                     -0.1         -0.4         -0.1
# FG                         10           88          126
# FGA                        31          221          238
# FG%                     0.323        0.398        0.529
# 3P                          0           33            0
# 3PA                         0           99            3
# 3P%                       NaN        0.333            0
# 2P                         10           55          126
# 2PA                        31          122          235
# 2P%                     0.323        0.451        0.536
# eFG%                    0.323        0.473        0.529
# FT                          3           31           32
# FTA                         5           40           49
# FT%                       0.6        0.775        0.653
# ORB                        11           15           41
# DRB                        24          110          118
# TRB                        35          125          159
# AST                         4           36           30
# STL                         2           15           14
# BLK                         5           16           33
# TOV                         3           40           30
# PF                         17           78           66
# PTS                        23          240          284
#
# [53 rows x 24691 columns]

# %% [markdown]
# # Initialize an all_nba column to store all NBA team stats

# %%
zero_data = np.zeros(shape=(len(data),1))
zero_data.shape
data = data.assign(all_nba = zero_data)

# %%
# set the all nba team column

allnba = pd.read_csv('data/all_nba_teams_clean.csv')
# allnba.loc[allnba['Player'] == "LeBron James"]
allnba
# Out:
#        Year  all_nba            Player
# 0    2017.0        1      LeBron James
# 1    2017.0        1      Kevin Durant
# 2    2017.0        1     Anthony Davis
# 3    2017.0        1      James Harden
# 4    2017.0        1    Damian Lillard
# ..      ...      ...               ...
# 775  1955.0        2    Maurice Stokes
# 776  1955.0        2     Dolph Schayes
# 777  1955.0        2  Clyde Lovellette
# 778  1955.0        2       Jack George
# 779  1955.0        2     Slater Martin
#
# [780 rows x 3 columns]

# %%
# update the all_nba column with the new all_nba stats

res = allnba.set_index(['Year', 'Player'])\
         .combine_first(data.set_index(['Year', 'Player']))\
         .reset_index()

res.T

# Check LeBron's all_nba teams
# res.loc[res['Player'] == "LeBron James"].T

# res

# #
# res.drop(['Year'],[''])

# Looks good! Let's do some one-hot encoding
# one_hot = pd.get_dummies(res, prefix=['all_nba'])
# Out:
#                 0          1          2          3          4           5      \
# Year             1950       1950       1950       1950       1950        1950
# Player      Al Cervi*  Al Guokas  Al Guokas  Al Guokas  Al Miksis  Alex Groza
# 2P                143         93         86          7          5         521
# 2P%             0.332      0.311      0.317       0.25      0.238       0.478
# 2PA               431        299        271         28         21        1090
# 3P                NaN        NaN        NaN        NaN        NaN         NaN
# 3P%               NaN        NaN        NaN        NaN        NaN         NaN
# 3PA               NaN        NaN        NaN        NaN        NaN         NaN
# 3PAr              NaN        NaN        NaN        NaN        NaN         NaN
# AST               264         95         85         10          4         162
# AST%              NaN        NaN        NaN        NaN        NaN         NaN
# Age                32         24         24         24         21          23
# BLK               NaN        NaN        NaN        NaN        NaN         NaN
# BLK%              NaN        NaN        NaN        NaN        NaN         NaN
# BPM               NaN        NaN        NaN        NaN        NaN         NaN
# DBPM              NaN        NaN        NaN        NaN        NaN         NaN
# DRB               NaN        NaN        NaN        NaN        NaN         NaN
# DRB%              NaN        NaN        NaN        NaN        NaN         NaN
# DWS               3.4       -0.1       -0.4        0.3          0         1.4
# FG                143         93         86          7          5         521
# FG%             0.332      0.311      0.317       0.25      0.238       0.478
# FGA               431        299        271         28         21        1090
# FT                287         28         25          3         17         454
# FT%             0.829       0.56      0.532          1       0.81       0.729
# FTA               346         50         47          3         21         623
# FTr             0.803      0.167      0.173      0.107          1       0.572
# G                  56         57         41         16          8          64
# GS                NaN        NaN        NaN        NaN        NaN         NaN
# MP                NaN        NaN        NaN        NaN        NaN         NaN
# OBPM              NaN        NaN        NaN        NaN        NaN         NaN
# ORB               NaN        NaN        NaN        NaN        NaN         NaN
# ORB%              NaN        NaN        NaN        NaN        NaN         NaN
# OWS               5.9       -0.9       -0.7       -0.2        0.2        16.5
# PER               NaN        NaN        NaN        NaN        NaN         NaN
# PF                223        143        116         27         22         221
# PTS               573        214        197         17         27        1496
# Pos                PG        F-G        F-G        F-G          C           C
# STL               NaN        NaN        NaN        NaN        NaN         NaN
# STL%              NaN        NaN        NaN        NaN        NaN         NaN
# TOV               NaN        NaN        NaN        NaN        NaN         NaN
# TOV%              NaN        NaN        NaN        NaN        NaN         NaN
# TRB               NaN        NaN        NaN        NaN        NaN         NaN
# TRB%              NaN        NaN        NaN        NaN        NaN         NaN
# TS%             0.491      0.333      0.338       0.29      0.446       0.548
# Tm                SYR        TOT        DNN        PHW        WAT         INO
# USG%              NaN        NaN        NaN        NaN        NaN         NaN
# Unnamed: 0         32         85         86         87        174          84
# VORP              NaN        NaN        NaN        NaN        NaN         NaN
# WS                9.3         -1       -1.1        0.1        0.1        17.9
# WS/48             NaN        NaN        NaN        NaN        NaN         NaN
# all_nba             0          0          0          0          0           0
# blank2            NaN        NaN        NaN        NaN        NaN         NaN
# blanl             NaN        NaN        NaN        NaN        NaN         NaN
# eFG%            0.332      0.311      0.317       0.25      0.238       0.478
#
#                    6              7            8               9      ...  \
# Year                1950           1950         1950            1950  ...
# Player      Alex Hannum*  Andrew Levane  Andy Duncan  Andy O'Donnell  ...
# 2P                   177            139          125              38  ...
# 2P%                0.363          0.333        0.433           0.352  ...
# 2PA                  488            418          289             108  ...
# 3P                   NaN            NaN          NaN             NaN  ...
# 3P%                  NaN            NaN          NaN             NaN  ...
# 3PA                  NaN            NaN          NaN             NaN  ...
# 3PAr                 NaN            NaN          NaN             NaN  ...
# AST                  129            156           42              17  ...
# AST%                 NaN            NaN          NaN             NaN  ...
# Age                   26             29           27              24  ...
# BLK                  NaN            NaN          NaN             NaN  ...
# BLK%                 NaN            NaN          NaN             NaN  ...
# BPM                  NaN            NaN          NaN             NaN  ...
# DBPM                 NaN            NaN          NaN             NaN  ...
# DRB                  NaN            NaN          NaN             NaN  ...
# DRB%                 NaN            NaN          NaN             NaN  ...
# DWS                  3.2              2          1.4             0.3  ...
# FG                   177            139          125              38  ...
# FG%                0.363          0.333        0.433           0.352  ...
# FGA                  488            418          289             108  ...
# FT                   128             54           60              14  ...
# FT%                0.688          0.635        0.556           0.778  ...
# FTA                  186             85          108              18  ...
# FTr                0.381          0.203        0.374           0.167  ...
# G                     64             60           67              25  ...
# GS                   NaN            NaN          NaN             NaN  ...
# MP                   NaN            NaN          NaN             NaN  ...
# OBPM                 NaN            NaN          NaN             NaN  ...
# ORB                  NaN            NaN          NaN             NaN  ...
# ORB%                 NaN            NaN          NaN             NaN  ...
# OWS                    2           -0.2            2             0.1  ...
# PER                  NaN            NaN          NaN             NaN  ...
# PF                   264            106          160              32  ...
# PTS                  482            332          310              90  ...
# Pos                   PF            F-G          F-C               G  ...
# STL                  NaN            NaN          NaN             NaN  ...
# STL%                 NaN            NaN          NaN             NaN  ...
# TOV                  NaN            NaN          NaN             NaN  ...
# TOV%                 NaN            NaN          NaN             NaN  ...
# TRB                  NaN            NaN          NaN             NaN  ...
# TRB%                 NaN            NaN          NaN             NaN  ...
# TS%                0.423          0.365        0.461           0.388  ...
# Tm                   SYR            SYR          ROC             BLB  ...
# USG%                 NaN            NaN          NaN             NaN  ...
# Unnamed: 0            92            139           55             199  ...
# VORP                 NaN            NaN          NaN             NaN  ...
# WS                   5.1            1.8          3.4             0.3  ...
# WS/48                NaN            NaN          NaN             NaN  ...
# all_nba                0              0            0               0  ...
# blank2               NaN            NaN          NaN             NaN  ...
# blanl                NaN            NaN          NaN             NaN  ...
# eFG%               0.363          0.333        0.433           0.352  ...
#
#                           25123        25124              25125  \
# Year                       2017         2017               2017
# Player      Willie Cauley-Stein  Willie Reed  Willy Hernangomez
# 2P                          255          161                242
# 2P%                       0.532        0.573              0.538
# 2PA                         479          281                450
# 3P                            0            1                  4
# 3P%                           0         0.25              0.267
# 3PA                           2            4                 15
# 3PAr                      0.004        0.014              0.032
# AST                          80           26                 96
# AST%                        9.4          3.9               11.5
# Age                          23           26                 22
# BLK                          45           47                 36
# BLK%                        2.9          3.6                2.2
# BPM                        -1.1         -0.6                  0
# DBPM                        0.9          0.7                0.6
# DRB                         255          203                332
# DRB%                       20.5           22               27.1
# DWS                         1.5          1.5                1.6
# FG                          255          162                246
# FG%                        0.53        0.568              0.529
# FGA                         481          285                465
# FT                          101           49                 91
# FT%                       0.669        0.557              0.728
# FTA                         151           88                125
# FTr                       0.314        0.309              0.269
# G                            75           71                 72
# GS                           21            5                 22
# MP                         1421         1031               1324
# OBPM                         -2         -1.3               -0.6
# ORB                          85          129                170
# ORB%                          7         13.7               13.8
# OWS                         1.4          2.1                1.8
# PER                        16.4         17.1               18.9
# PF                          147          137                150
# PTS                         611          374                587
# Pos                           C            C                  C
# STL                          53           18                 41
# STL%                        1.9          0.9                1.5
# TOV                          69           31                100
# TOV%                       11.2          8.7               16.1
# TRB                         340          332                502
# TRB%                       13.8         17.8               20.4
# TS%                       0.558        0.578              0.564
# Tm                          SAC          MIA                NYK
# USG%                       19.6         15.3               20.3
# Unnamed: 0                24190        24552              24325
# VORP                        0.3          0.4                0.7
# WS                            3          3.6                3.4
# WS/48                       0.1        0.168              0.123
# all_nba                       0            0                  0
# blank2                      NaN          NaN                NaN
# blanl                       NaN          NaN                NaN
# eFG%                       0.53         0.57              0.533
#
#                       25126         25127         25128         25129  \
# Year                   2017          2017          2017          2017
# Player      Wilson Chandler  Yogi Ferrell  Yogi Ferrell  Yogi Ferrell
# 2P                      323            92            10            82
# 2P%                   0.527         0.422         0.455         0.418
# 2PA                     613           218            22           196
# 3P                      110            68             8            60
# 3P%                   0.337         0.386         0.296         0.403
# 3PA                     326           176            27           149
# 3PAr                  0.347         0.447         0.551         0.432
# AST                     141           172            17           155
# AST%                    9.8          23.2          16.9          24.1
# Age                      29            23            23            23
# BLK                      30             9             2             7
# BLK%                    1.1           0.7             1           0.6
# BPM                    -0.8          -0.7          -7.3           0.2
# DBPM                   -1.3          -0.7          -3.3          -0.3
# DRB                     356            91             8            83
# DRB%                   17.7           9.2           5.5           9.7
# DWS                     1.1             1             0           0.9
# FG                      433           160            18           142
# FG%                   0.461         0.406         0.367         0.412
# FGA                     939           394            49           345
# FT                      141            74            10            64
# FT%                   0.727         0.831         0.625         0.877
# FTA                     194            89            16            73
# FTr                   0.207         0.226         0.327         0.212
# G                        71            46            10            36
# GS                       33            29             0            29
# MP                     2197          1197           151          1046
# OBPM                    0.5          -0.1            -4           0.5
# ORB                     103            20             4            16
# ORB%                    5.2           1.8           2.8           1.7
# OWS                     2.4           0.8          -0.2             1
# PER                    14.9          13.1           6.5          14.1
# PF                      172            90            11            79
# PTS                    1117           462            54           408
# Pos                      SF            PG            PG            PG
# STL                      52            42             2            40
# STL%                    1.2           1.8           0.6             2
# TOV                     114            70            14            56
# TOV%                     10          13.9            20          12.9
# TRB                     459           111            12            99
# TRB%                   11.5           5.3           4.2           5.5
# TS%                   0.545         0.533         0.482         0.541
# Tm                      DEN           TOT           BRK           DAL
# USG%                     22          19.6          19.9          19.5
# Unnamed: 0            24192         24259         24260         24261
# VORP                    0.7           0.4          -0.2           0.6
# WS                      3.6           1.8          -0.2             2
# WS/48                 0.078         0.072         -0.05          0.09
# all_nba                   0             0             0             0
# blank2                  NaN           NaN           NaN           NaN
# blanl                   NaN           NaN           NaN           NaN
# eFG%                   0.52         0.492         0.449         0.499
#
#                   25130          25131          25132
# Year               2017           2017           2017
# Player      Zach LaVine  Zach Randolph  Zaza Pachulia
# 2P                  206            412            164
# 2P%               0.515          0.474          0.538
# 2PA                 400            870            305
# 3P                  120             21              0
# 3P%               0.387          0.223              0
# 3PA                 310             94              2
# 3PAr              0.437          0.098          0.007
# AST                 139            122            132
# AST%               12.6           13.5           13.6
# Age                  21             35             32
# BLK                  10             10             33
# BLK%                0.5            0.5              2
# BPM                -0.3           -2.1            2.7
# DBPM               -2.4           -0.7              3
# DRB                 141            416            270
# DRB%                9.5           27.4             22
# DWS                 0.4            2.4            2.5
# FG                  326            433            164
# FG%               0.459          0.449          0.534
# FGA                 710            964            307
# FT                  117            141             98
# FT%               0.836          0.731          0.778
# FTA                 140            193            126
# FTr               0.197            0.2           0.41
# G                    47             73             70
# GS                   47              5             70
# MP                 1749           1786           1268
# OBPM                2.1           -1.4           -0.3
# ORB                  18            182            140
# ORB%                1.2           11.3           12.9
# OWS                 2.5            0.8            2.2
# PER                14.6           18.5           16.1
# PF                  104            136            166
# PTS                 889           1028            426
# Pos                  SG             PF              C
# STL                  41             38             59
# STL%                1.2            1.1            2.2
# TOV                  85             99             88
# TOV%                9.9            8.6           19.5
# TRB                 159            598            410
# TRB%                5.3           19.1           17.7
# TS%               0.576           0.49          0.588
# Tm                  MIN            MEM            GSW
# USG%               21.7           29.2           15.3
# Unnamed: 0        24408          24550          24515
# VORP                0.8              0            1.5
# WS                    3            3.2            4.7
# WS/48             0.082          0.086          0.177
# all_nba               0              0              0
# blank2              NaN            NaN            NaN
# blanl               NaN            NaN            NaN
# eFG%              0.544           0.46          0.534
#
# [54 rows x 25133 columns]

# %% [markdown]
# # Columns
#
# ```
# 2P
# 2P%
# 2PA
# 3P
# 3P%
# 3PA
# AST
# AST%
# BLK
# BLK%
# BPM
# DRB
# DRB%
# eFG%
# FG
# FG%
# FGA
# FT
# FT%
# FTA
# G
# GS
# MP
# ORB
# OBR%
# PER
# PF
# STL
# STL%
# TOV
# TOV%
# TRB
# TRB%
# TS%
# WS
# WS/48
# ```

# %%
# create the dataset for ML

df_1955 = res[res.Year > 1955]
df_ml = df_1955[['2P', '2P%', '2PA', '3P', '3P%', '3PA', 'AST', 
                 'AST%', 'BLK', 'BLK%', 'BPM', 'DRB',  
                 'eFG%', 'FG', 'FGA', 'FT', 'FT%', 'FTA', 
                 'G', 'GS', 'MP', 'ORB', 'ORB%', 'PER', 'PF', 'STL', 
                 'TOV', 'TOV%', 'TRB', 'TRB%', 'TS%', 
                 'WS', 'WS/48']].copy()

df_anba = df_1955[['all_nba']].copy()


from sklearn.model_selection import train_test_split
# X, y = df_ml.iloc[:, :-1], res.iloc[:, -1]



X_train, X_test, y_train, y_test = train_test_split(df_ml, df_anba, test_size=0.2, random_state=123)

# %%
import xgboost as xgb
data_dmatrix = xgb.DMatrix(data=df_ml,label=df_anba)

xg_reg = xgb.XGBRegressor(objective='reg:squarederror', learning_rate=0.1, max_depth=4, scale_pos_weight=31)

xg_reg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=4, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, num_parallel_tree=1, objective='reg:squarederror',
#              random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#              subsample=1, tree_method='auto', verbosity=1)

# %%
preds = xg_reg.predict(X_test)
preds
# Out:
# array([0.0001983, 0.0001983, 0.0001983, ..., 0.0001983, 0.0001983,
#        0.0001983], dtype=float32)

# %%
rmse = np.sqrt(mean_squared_error(y_test, preds))
rmse
# Out:
# 0.2655279088473675

# %%
params = {'learning_rate': 0.1, 'max_depth': 5, "objective": "reg:squarederror",
          'tree_method': 'hist'}
cv_results = xgb.cv(dtrain=data_dmatrix, params=params, nfold=3,
                    num_boost_round=50, early_stopping_rounds=10, metrics="mae", as_pandas=True, seed=123)
cv_results.head(10)
# Out:
#    train-mae-mean  train-mae-std  test-mae-mean  test-mae-std
# 0        0.477796       0.000616       0.478236      0.001127
# 1        0.434352       0.000653       0.435156      0.001168
# 2        0.395295       0.000672       0.396400      0.001172
# 3        0.359980       0.000752       0.361415      0.001159
# 4        0.328250       0.000813       0.329996      0.001090
# 5        0.300042       0.000957       0.302059      0.000897
# 6        0.275293       0.001061       0.277594      0.000794
# 7        0.253031       0.001006       0.255522      0.000742
# 8        0.232953       0.001074       0.235763      0.000592
# 9        0.214834       0.001066       0.217866      0.000621

# %%
xgb.plot_importance(xg_reg)
plt.rcParams['figure.figsize'] = [10, 10]
plt
# Out:
# <module 'matplotlib' from '/home/pjames/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py'>
